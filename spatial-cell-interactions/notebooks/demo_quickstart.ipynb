# %% [markdown]
# # Demo Quickstart
#
# Run the CLI scripts from the project root:
# ```bash
# python scripts/05_run_end_to_end.py --visium_path data/external/visium_sample/outs/ --run_name demo
# ```
# Inspect outputs under `results/demo/`.
